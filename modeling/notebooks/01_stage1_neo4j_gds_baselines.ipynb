# %% [markdown]
# # Stage 1 — Neo4j GDS / tabular baseline
#
# This notebook trains the memory-safe Stage 1 baseline on the PRING pair table. It works with either a full PRING run folder, `<run>/graph/ml/modeling`, or the standalone attached `stage1_neo4j_gds_baselines` folder.

# %%
from pathlib import Path
 
# Change this path when running locally or inside Docker.
MODEL_INPUT = Path("A:/Repositories/PRING/runs/cyp450_5enzymes_uncapped_raw_rematerialized/graph/ml/modeling/stage1_neo4j_gds_baselines")
OUTPUT_DIR = Path("/models/notebook_stage1_tabular")
REPORT_DIR = Path("/reports/modeling")

# %%
import sys
from pathlib import Path

HERE = Path.cwd().resolve()
MODELING_ROOT = None

for candidate in [HERE, *HERE.parents]:
    if (candidate / "pring_modeling").is_dir():
        MODELING_ROOT = candidate
        break
    if (candidate / "modeling" / "pring_modeling").is_dir():
        MODELING_ROOT = candidate / "modeling"
        break

if MODELING_ROOT is None:
    raise RuntimeError(
        "Could not find pring_modeling. Open the notebook from the project/modeling folder "
        "or install it with: pip install -e ./modeling"
    )

if str(MODELING_ROOT) not in sys.path:
    sys.path.insert(0, str(MODELING_ROOT))

print(f"Using pring_modeling from: {MODELING_ROOT}")
# Out:
# Using pring_modeling from: A:\Repositories\KG-ADMET-Predictor\modeling

# %%
from pring_modeling.stage1_tabular import build_parser, run

args = build_parser().parse_args([
    "--modeling-dir", str(MODEL_INPUT),
    "--output-dir", str(OUTPUT_DIR),
    "--report-dir", str(REPORT_DIR),
    "--max-training-rows", "100000",
    "--max-scoring-rows", "100000",
    "--n-estimators", "200",
])
summary = run(args)
summary

args = build_parser().parse_args([
    "--modeling-dir", str(MODEL_INPUT),
    "--output-dir", str(OUTPUT_DIR),
    "--report-dir", str(REPORT_DIR),
    "--max-training-rows", "100000",
    "--max-scoring-rows", "100000",
    "--n-estimators", "200",
])
summary = run(args)
summary
# Out:
# 2026-06-08 03:09:06.555 | INFO     | pring_modeling.stage1_tabular:run:118 - Stage 1 directory: A:\Repositories\PRING\runs\cyp450_5enzymes_uncapped_raw_rematerialized\graph\ml\modeling\stage1_neo4j_gds_baselines
# 2026-06-08 03:09:06.556 | INFO     | pring_modeling.stage1_tabular:run:119 - Training file: A:\Repositories\PRING\runs\cyp450_5enzymes_uncapped_raw_rematerialized\graph\ml\modeling\stage1_neo4j_gds_baselines\compound_target_training_pairs_for_gds.csv
# 2026-06-08 03:09:06.556 | INFO     | pring_modeling.stage1_tabular:run:121 - Candidate scoring file: A:\Repositories\PRING\runs\cyp450_5enzymes_uncapped_raw_rematerialized\graph\ml\modeling\stage1_neo4j_gds_baselines\candidate_pairs_for_gds_scoring.csv
# 2026-06-08 03:09:10.016 | INFO     | pring_modeling.stage1_tabular:run:118 - Stage 1 directory: A:\Repositories\PRING\runs\cyp450_5enzymes_uncapped_raw_rematerialized\graph\ml\modeling\stage1_neo4j_gds_baselines
# 2026-06-08 03:09:10.018 | INFO     | pring_modeling.stage1_tabular:run:119 - Training file: A:\Repositories\PRING\runs\cyp450_5enzymes_uncapped_raw_rematerialized\graph\ml\modeling\stage1_neo4j_gds_baselines\compound_target_training_pairs_for_gds.csv
# 2026-06-08 03:09:10.018 | INFO     | pring_modeling.stage1_tabular:run:121 - Candidate scoring file: A:\Repositories\PRING\runs\cyp450_5enzymes_uncapped_raw_rematerialized\graph\ml\modeling\stage1_neo4j_gds_baselines\candidate_pairs_for_gds_scoring.csv
# {'stage': 'Stage 1 — Neo4j GDS/tabular baseline',
#  'model': 'stage1_tabular_random_forest',
#  'status': 'trained',
#  'stage_dir': 'A:\\Repositories\\PRING\\runs\\cyp450_5enzymes_uncapped_raw_rematerialized\\graph\\ml\\modeling\\stage1_neo4j_gds_baselines',
#  'training_file': 'A:\\Repositories\\PRING\\runs\\cyp450_5enzymes_uncapped_raw_rematerialized\\graph\\ml\\modeling\\stage1_neo4j_gds_baselines\\compound_target_training_pairs_for_gds.csv',
#  'candidate_file': 'A:\\Repositories\\PRING\\runs\\cyp450_5enzymes_uncapped_raw_rematerialized\\graph\\ml\\modeling\\stage1_neo4j_gds_baselines\\candidate_pairs_for_gds_scoring.csv',
#  'training_rows_used': 38753,
#  'feature_count': 15,
#  'prediction_scope': 'candidates',
#  'prediction_rows_written': 100000,
#  'model_file': '\\models\\notebook_stage1_tabular\\stage1_tabular_random_forest.joblib',
#  'predictions_file': '\\models\\notebook_stage1_tabular\\predictions.csv',
#  'metrics': {'roc_auc': 1.0,
#   'average_precision': 1.0,
#   'accuracy': 1.0,
#   'f1': 1.0,
#   'precision': 1.0,
#   'recall': 1.0}}

# %%
import pandas as pd

pred = pd.read_csv(OUTPUT_DIR / "predictions.csv")
pred.tail()
# Out:
#        compound_node_id       compound_node_ref  protein_node_id  \
# 99995            609363   Compound|cid=65459349          2865021
# 99996            477494   Compound|cid=45255157          2865020
# 99997            108750  Compound|cid=122485308          2865022
# 99998            579796   Compound|cid=59016734          2865020
# 99999            656133    Compound|cid=6918840          2865019
#
#                 protein_node_ref    label  split             split_group  \
# 99995  Protein|protein_id=P10635  unknown    val     Compound|cid=100000
# 99996  Protein|protein_id=P08684  unknown   test    Compound|cid=1010346
# 99997  Protein|protein_id=P11712  unknown    val     Compound|cid=100000
# 99998  Protein|protein_id=P08684  unknown    val   Compound|cid=10017774
# 99999  Protein|protein_id=P05177  unknown  train  Compound|cid=101095517
#
#                                   stage_use target_relation  \
# 99995  candidate_to_score_not_true_negative  INTERACTS_WITH
# 99996  candidate_to_score_not_true_negative  INTERACTS_WITH
# 99997  candidate_to_score_not_true_negative  INTERACTS_WITH
# 99998  candidate_to_score_not_true_negative  INTERACTS_WITH
# 99999  candidate_to_score_not_true_negative  INTERACTS_WITH
#
#                candidate_sampling_method  score  predicted_label  \
# 99995  unobserved_within_extracted_scope    1.0                1
# 99996  unobserved_within_extracted_scope    1.0                1
# 99997  unobserved_within_extracted_scope    1.0                1
# 99998  unobserved_within_extracted_scope    1.0                1
# 99999  unobserved_within_extracted_scope    1.0                1
#
#                               model                                 stage
# 99995  stage1_tabular_random_forest  Stage 1 — Neo4j GDS/tabular baseline
# 99996  stage1_tabular_random_forest  Stage 1 — Neo4j GDS/tabular baseline
# 99997  stage1_tabular_random_forest  Stage 1 — Neo4j GDS/tabular baseline
# 99998  stage1_tabular_random_forest  Stage 1 — Neo4j GDS/tabular baseline
# 99999  stage1_tabular_random_forest  Stage 1 — Neo4j GDS/tabular baseline

# %% [markdown]
# ## Optional: train MLP on exported GDS embeddings
#
# Run this only after exporting FastRP/GraphSAGE embeddings from Neo4j GDS to a CSV containing `node_id`/`node_ref` and `embedding`.

# %%
from pring_modeling.stage1_mlp_gds import build_parser as mlp_parser, run as run_mlp
EMBEDDING_CSV = Path("/models/gds_embeddings.csv")
args = mlp_parser().parse_args([
    "--modeling-dir", str(MODEL_INPUT),
    "--embedding-csv", str(EMBEDDING_CSV),
    "--output-dir", "/models/notebook_stage1_mlp",
    "--epochs", "30",
])
run_mlp(args)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from pring_modeling.stage1_mlp_gds import build_parser as mlp_parser, run as run_mlp
#       2 EMBEDDING_CSV = Path("/models/gds_embeddings.csv")
#       3 args = mlp_parser().parse_args([
#       4     "--modeling-dir", str(MODEL_INPUT),
#       5     "--embedding-csv", str(EMBEDDING_CSV),
#       6     "--output-dir", "/models/notebook_stage1_mlp",
#       7     "--epochs", "30",
#       8 ])
#
# File A:\Repositories\KG-ADMET-Predictor\modeling\pring_modeling\stage1_mlp_gds.py:10
#       8 import numpy as np
#       9 import pandas as pd
# ---> 10 import torch
#      11 from sklearn.model_selection import train_test_split
#      12 from torch import nn
#
# ModuleNotFoundError: No module named 'torch'
